# %% [markdown]
# ## Contents<a id='3.1_Contents'></a>
# * [1 Image Segmentation](#1-Image-Segmentation)
#   * [1.1 Introduction](#1.1-Introduction)
#   * [1.2 Imports](#1.2-Imports)
#   * [1.3 Load the data](#1.3-Load-the-data)
#   * [1.4 Annotation Extraction](#1.4-Annotation-Extraction)
#   * [1.5 Processing and saving the images](#1.5-Processing-and-saving-the-images)

# %% [markdown]
# # 1.1 Introduction

# %% [markdown]
# The dataset for our Capstone Three project is also sourced from Kaggle. https://www.kaggle.com/datasets/rrighart/jarlids. At the time of downloading the dataset, it contained 168 image files which contained 1859 jar lids. There are two categories intact (962) and damaged (897) jar lids.
#
# In our first notebook we will segment the individual jar lids from the 168 images with proper labels. To do this we will use the jarlids_annots.csv file with bounding boxes. Which was manually created with VGG Image Annotator (VIA)

# %% [markdown]
# # 1.2 Imports

# %%
import os
import cv2
import pandas as pd
import ast  # To parse dictionary strings

# %%
# Paths
image_folder = "Jarlids"
annotation_file = "jarlids_annots.csv"
output_dir = "cropped_lids"
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# # 1.3 Load the data

# %%
df = pd.read_csv("jarlids_annots.csv", index_col=0)  

df.head()
# Out:
#   filename  file_size file_attributes  region_count  region_id  \
# 0   p1.JPG     167996              {}            12          0
# 1   p1.JPG     167996              {}            12          1
# 2   p1.JPG     167996              {}            12          2
# 3   p1.JPG     167996              {}            12          3
# 4   p1.JPG     167996              {}            12          4
#
#                              region_shape_attributes   region_attributes
# 0  {"name":"rect","x":70,"y":46,"width":120,"heig...   {"type":"intact"}
# 1  {"name":"rect","x":195,"y":60,"width":118,"hei...   {"type":"intact"}
# 2  {"name":"rect","x":318,"y":25,"width":144,"hei...  {"type":"damaged"}
# 3  {"name":"rect","x":474,"y":13,"width":135,"hei...   {"type":"intact"}
# 4  {"name":"rect","x":45,"y":162,"width":123,"hei...   {"type":"intact"}

# %%
for idx, col in enumerate(df.columns):
    print(f"index: {idx} : {col}")
# Out:
# index: 0 : filename
# index: 1 : file_size
# index: 2 : file_attributes
# index: 3 : region_count
# index: 4 : region_id
# index: 5 : region_shape_attributes
# index: 6 : region_attributes

# %% [markdown]
# # 1.4 Annotation Extraction

# %%
# Annotation extraction script — it's processing rows from a Pandas DataFrame where each row represents a region of interest (ROI) in an image 
# (aka a bounding box around a jar lid)

annotations = []
for _, row in df.iterrows():
    try:
        image_name = row["filename"]  

        # Converts the bounding box info from a string into a dictionary.
        bbox_info = ast.literal_eval(row["region_shape_attributes"]) 

        #  This parses label metadata from a string.
        label_info = ast.literal_eval(row["region_attributes"])  # Only allows literals like dicts, lists, strings, etc., not arbitrary code.

        annotations.append([
            image_name, 
            bbox_info["x"], bbox_info["y"], 
            bbox_info["width"], bbox_info["height"], 
            label_info["type"]
        ])
    except Exception as e:
        print(f"Skipping row due to error: {row}\nError: {e}")

print(f"Successfully processed {len(annotations)} annotations.")
# Out:
# Successfully processed 1859 annotations.

# %%
annotations
# Out:
# [['p1.JPG', 70, 46, 120, 112, 'intact'],
#  ['p1.JPG', 195, 60, 118, 99, 'intact'],
#  ['p1.JPG', 318, 25, 144, 120, 'damaged'],
#  ['p1.JPG', 474, 13, 135, 122, 'intact'],
#  ['p1.JPG', 45, 162, 123, 116, 'intact'],
#  ['p1.JPG', 174, 166, 137, 130, 'intact'],
#  ['p1.JPG', 318, 146, 158, 148, 'intact'],
#  ['p1.JPG', 473, 150, 138, 144, 'intact'],
#  ['p1.JPG', 51, 291, 135, 141, 'intact'],
#  ['p1.JPG', 193, 314, 135, 138, 'intact'],
#  ['p1.JPG', 335, 309, 132, 132, 'intact'],
#  ['p1.JPG', 481, 310, 134, 139, 'damaged'],
#  ['p2.JPG', 77, 2, 148, 132, 'damaged'],
#  ['p2.JPG', 237, 8, 132, 118, 'intact'],
#  ['p2.JPG', 376, 1, 119, 102, 'intact'],
#  ['p2.JPG', 495, 18, 122, 116, 'intact'],
#  ['p2.JPG', 57, 153, 131, 122, 'damaged'],
#  ['p2.JPG', 212, 141, 128, 123, 'intact'],
#  ['p2.JPG', 354, 111, 136, 131, 'intact'],
#  ['p2.JPG', 492, 140, 112, 110, 'intact'],
#  ['p2.JPG', 6, 283, 168, 166, 'intact'],
#  ['p2.JPG', 200, 272, 129, 130, 'intact'],
#  ['p2.JPG', 334, 249, 158, 152, 'intact'],
#  ['p2.JPG', 509, 256, 129, 140, 'intact'],
#  ['p3.JPG', 79, 1, 133, 104, 'intact'],
#  ['p3.JPG', 216, 9, 139, 112, 'intact'],
#  ['p3.JPG', 365, 10, 152, 126, 'intact'],
#  ['p3.JPG', 46, 150, 165, 123, 'intact'],
#  ['p3.JPG', 215, 173, 157, 135, 'intact'],
#  ['p3.JPG', 377, 161, 148, 133, 'intact'],
#  ['p3.JPG', 16, 234, 214, 204, 'damaged'],
#  ['p3.JPG', 236, 299, 168, 168, 'damaged'],
#  ['p3.JPG', 450, 258, 184, 205, 'intact'],
#  ['p4.JPG', 71, 50, 133, 118, 'intact'],
#  ['p4.JPG', 213, 48, 140, 128, 'intact'],
#  ['p4.JPG', 355, 55, 116, 99, 'intact'],
#  ['p4.JPG', 500, 2, 139, 124, 'intact'],
#  ['p4.JPG', 75, 200, 110, 110, 'intact'],
#  ['p4.JPG', 187, 194, 138, 140, 'intact'],
#  ['p4.JPG', 324, 139, 174, 156, 'intact'],
#  ['p4.JPG', 492, 167, 133, 129, 'damaged'],
#  ['p4.JPG', 3, 302, 131, 141, 'intact'],
#  ['p4.JPG', 132, 337, 130, 140, 'intact'],
#  ['p4.JPG', 266, 304, 168, 173, 'damaged'],
#  ['p4.JPG', 421, 285, 135, 135, 'intact'],
#  ['p5.JPG', 246, 2, 138, 126, 'damaged'],
#  ['p5.JPG', 132, 66, 119, 103, 'intact'],
#  ['p5.JPG', 43, 151, 132, 126, 'damaged'],
#  ['p5.JPG', 172, 138, 162, 152, 'intact'],
#  ['p5.JPG', 340, 120, 127, 129, 'intact'],
#  ['p5.JPG', 468, 153, 112, 107, 'intact'],
#  ['p5.JPG', 2, 277, 137, 164, 'intact'],
#  ['p5.JPG', 174, 305, 133, 131, 'intact'],
#  ['p5.JPG', 311, 255, 149, 157, 'intact'],
#  ['p5.JPG', 479, 257, 141, 147, 'intact'],
#  ['p6.JPG', 107, 10, 238, 208, 'damaged'],
#  ['p6.JPG', 348, 72, 194, 171, 'intact'],
#  ['p6.JPG', 94, 255, 219, 221, 'damaged'],
#  ['p6.JPG', 347, 263, 220, 210, 'intact'],
#  ['p7.JPG', 30, 6, 218, 201, 'intact'],
#  ['p7.JPG', 261, 32, 207, 186, 'damaged'],
#  ['p7.JPG', 452, 108, 156, 151, 'damaged'],
#  ['p7.JPG', 65, 245, 184, 182, 'intact'],
#  ['p7.JPG', 260, 263, 182, 183, 'intact'],
#  ['p7.JPG', 447, 278, 178, 182, 'intact'],
#  ['p8.JPG', 16, 11, 202, 189, 'intact'],
#  ['p8.JPG', 235, 22, 198, 182, 'damaged'],
#  ['p8.JPG', 425, 93, 160, 145, 'damaged'],
#  ['p8.JPG', 55, 237, 163, 166, 'intact'],
#  ['p8.JPG', 236, 250, 169, 169, 'intact'],
#  ['p8.JPG', 436, 241, 183, 180, 'damaged'],
#  ['p9.JPG', 7, 32, 212, 207, 'intact'],
#  ['p9.JPG', 236, 12, 217, 216, 'damaged'],
#  ['p9.JPG', 444, 73, 173, 173, 'damaged'],
#  ['p9.JPG', 70, 242, 167, 162, 'intact'],
#  ['p9.JPG', 254, 237, 167, 169, 'intact'],
#  ['p9.JPG', 449, 252, 183, 183, 'damaged'],
#  ['p10.JPG', 35, 28, 208, 208, 'damaged'],
#  ['p10.JPG', 238, 35, 225, 224, 'intact'],
#  ['p10.JPG', 428, 94, 157, 167, 'intact'],
#  ['p10.JPG', 99, 246, 168, 170, 'damaged'],
#  ['p10.JPG', 270, 264, 178, 181, 'damaged'],
#  ['p10.JPG', 450, 265, 164, 170, 'intact'],
#  ['p11.JPG', 2, 7, 204, 172, 'damaged'],
#  ['p11.JPG', 202, 2, 233, 166, 'intact'],
#  ['p11.JPG', 382, 121, 182, 150, 'intact'],
#  ['p11.JPG', 4, 224, 216, 202, 'damaged'],
#  ['p11.JPG', 222, 238, 219, 219, 'damaged'],
#  ['p11.JPG', 436, 250, 201, 202, 'intact'],
#  ['p12.JPG', 53, 7, 494, 466, 'damaged'],
#  ['p13.JPG', 61, 99, 128, 120, 'intact'],
#  ['p13.JPG', 184, 48, 128, 123, 'intact'],
#  ['p13.JPG', 299, 23, 108, 100, 'damaged'],
#  ['p13.JPG', 395, 70, 111, 102, 'intact'],
#  ['p13.JPG', 506, 68, 110, 106, 'intact'],
#  ['p13.JPG', 87, 229, 108, 103, 'intact'],
#  ['p13.JPG', 195, 185, 128, 125, 'intact'],
#  ['p13.JPG', 306, 125, 102, 107, 'damaged'],
#  ['p13.JPG', 396, 188, 100, 104, 'intact'],
#  ['p13.JPG', 191, 316, 109, 108, 'intact'],
#  ['p13.JPG', 299, 263, 111, 112, 'intact'],
#  ['p13.JPG', 489, 295, 126, 122, 'intact'],
#  ['p13.JPG', 525, 179, 111, 111, 'intact'],
#  ['p14.JPG', 5, 107, 137, 129, 'intact'],
#  ['p14.JPG', 147, 64, 132, 124, 'intact'],
#  ['p14.JPG', 277, 42, 107, 103, 'damaged'],
#  ['p14.JPG', 374, 89, 119, 110, 'intact'],
#  ['p14.JPG', 493, 96, 120, 110, 'intact'],
#  ['p14.JPG', 30, 249, 120, 113, 'intact'],
#  ['p14.JPG', 152, 209, 140, 136, 'intact'],
#  ['p14.JPG', 276, 147, 111, 112, 'damaged'],
#  ['p14.JPG', 365, 221, 116, 112, 'intact'],
#  ['p14.JPG', 508, 204, 128, 133, 'intact'],
#  ['p14.JPG', 133, 343, 126, 128, 'intact'],
#  ['p14.JPG', 263, 294, 124, 129, 'intact'],
#  ['p14.JPG', 473, 342, 139, 135, 'intact'],
#  ['p15.JPG', 37, 33, 138, 123, 'intact'],
#  ['p15.JPG', 187, 99, 121, 115, 'intact'],
#  ['p15.JPG', 307, 65, 127, 121, 'intact'],
#  ['p15.JPG', 447, 37, 123, 118, 'intact'],
#  ['p15.JPG', 7, 165, 126, 122, 'intact'],
#  ['p15.JPG', 125, 214, 127, 128, 'intact'],
#  ['p15.JPG', 254, 193, 124, 127, 'damaged'],
#  ['p15.JPG', 375, 157, 145, 140, 'intact'],
#  ['p15.JPG', 525, 174, 114, 120, 'intact'],
#  ['p15.JPG', 5, 292, 136, 141, 'intact'],
#  ['p15.JPG', 216, 323, 118, 118, 'damaged'],
#  ['p15.JPG', 343, 294, 149, 156, 'intact'],
#  ['p15.JPG', 503, 285, 134, 142, 'intact'],
#  ['p16.JPG', 3, 23, 130, 126, 'intact'],
#  ['p16.JPG', 153, 45, 115, 109, 'intact'],
#  ['p16.JPG', 255, 102, 113, 118, 'damaged'],
#  ['p16.JPG', 339, 25, 135, 134, 'intact'],
#  ['p16.JPG', 476, 2, 107, 100, 'intact'],
#  ['p16.JPG', 495, 76, 133, 132, 'intact'],
#  ['p16.JPG', 367, 147, 129, 133, 'intact'],
#  ['p16.JPG', 21, 167, 122, 115, 'intact'],
#  ['p16.JPG', 151, 165, 117, 118, 'intact'],
#  ['p16.JPG', 263, 226, 109, 109, 'damaged'],
#  ['p16.JPG', 73, 269, 132, 130, 'intact'],
#  ['p16.JPG', 363, 282, 124, 119, 'intact'],
#  ['p16.JPG', 490, 214, 107, 116, 'intact'],
#  ['p17.JPG', 2, 25, 162, 154, 'intact'],
#  ['p17.JPG', 168, 17, 166, 162, 'damaged'],
#  ['p17.JPG', 329, 64, 152, 148, 'intact'],
#  ['p17.JPG', 481, 22, 124, 124, 'intact'],
#  ['p17.JPG', 49, 201, 141, 133, 'intact'],
#  ['p17.JPG', 194, 193, 125, 115, 'intact'],
#  ['p17.JPG', 326, 219, 130, 128, 'damaged'],
#  ['p17.JPG', 449, 162, 126, 132, 'intact'],
#  ['p17.JPG', 70, 337, 140, 134, 'intact'],
#  ['p17.JPG', 212, 318, 130, 132, 'intact'],
#  ['p17.JPG', 338, 354, 120, 123, 'damaged'],
#  ['p17.JPG', 470, 316, 155, 155, 'intact'],
#  ['p18.JPG', 79, 6, 161, 152, 'intact'],
#  ['p18.JPG', 239, 26, 138, 127, 'damaged'],
#  ['p18.JPG', 380, 26, 127, 126, 'damaged'],
#  ['p18.JPG', 10, 136, 181, 174, 'damaged'],
#  ['p18.JPG', 208, 167, 130, 127, 'intact'],
#  ['p18.JPG', 337, 138, 140, 134, 'intact'],
#  ['p18.JPG', 13, 318, 170, 159, 'intact'],
#  ['p18.JPG', 209, 299, 148, 144, 'intact'],
#  ['p18.JPG', 358, 276, 139, 142, 'intact'],
#  ['p19.JPG', 91, 3, 237, 230, 'damaged'],
#  ['p19.JPG', 343, 71, 205, 196, 'damaged'],
#  ['p19.JPG', 101, 255, 228, 219, 'intact'],
#  ['p19.JPG', 331, 284, 193, 188, 'damaged'],
#  ['p20.JPG', 8, 30, 332, 335, 'damaged'],
#  ['p20.JPG', 356, 115, 261, 271, 'damaged'],
#  ['p21.JPG', 86, 13, 217, 212, 'damaged'],
#  ['p21.JPG', 311, 26, 213, 204, 'intact'],
#  ['p21.JPG', 83, 239, 220, 212, 'intact'],
#  ['p21.JPG', 310, 237, 238, 237, 'intact'],
#  ['p22.JPG', 67, 7, 241, 233, 'damaged'],
#  ['p22.JPG', 311, 23, 229, 229, 'intact'],
#  ['p22.JPG', 75, 249, 235, 226, 'intact'],
#  ['p22.JPG', 323, 249, 249, 227, 'intact'],
#  ['p23.JPG', 143, 23, 191, 188, 'intact'],
#  ['p23.JPG', 342, 18, 203, 199, 'damaged'],
#  ['p23.JPG', 117, 222, 218, 221, 'intact'],
#  ['p23.JPG', 336, 224, 202, 203, 'intact'],
#  ['p24.JPG', 12, 83, 280, 281, 'intact'],
#  ['p24.JPG', 299, 81, 279, 284, 'intact'],
#  ['p25.JPG', 150, 14, 223, 209, 'intact'],
#  ['p25.JPG', 379, 20, 223, 216, 'intact'],
#  ['p25.JPG', 12, 196, 245, 247, 'intact'],
#  ['p25.JPG', 265, 189, 240, 251, 'damaged'],
#  ['p26.JPG', 123, 15, 185, 180, 'intact'],
#  ['p26.JPG', 319, 21, 183, 174, 'intact'],
#  ['p26.JPG', 9, 154, 202, 203, 'intact'],
#  ['p26.JPG', 221, 154, 189, 196, 'damaged'],
#  ['p26.JPG', 417, 171, 210, 210, 'intact'],
#  ['p27.JPG', 117, 17, 229, 221, 'damaged'],
#  ['p27.JPG', 339, 29, 201, 191, 'damaged'],
#  ['p27.JPG', 125, 237, 219, 214, 'intact'],
#  ['p27.JPG', 347, 222, 233, 237, 'intact'],
#  ['p28.JPG', 143, 13, 225, 218, 'damaged'],
#  ['p28.JPG', 362, 16, 199, 193, 'damaged'],
#  ['p28.JPG', 153, 238, 213, 202, 'intact'],
#  ['p28.JPG', 363, 206, 232, 229, 'intact'],
#  ['p29.JPG', 131, 23, 231, 225, 'damaged'],
#  ['p29.JPG', 356, 30, 202, 190, 'damaged'],
#  ['p29.JPG', 143, 255, 213, 212, 'intact'],
#  ['p29.JPG', 357, 225, 237, 238, 'intact'],
#  ['p30.JPG', 115, 33, 208, 187, 'damaged'],
#  ['p30.JPG', 321, 15, 231, 211, 'intact'],
#  ['p30.JPG', 93, 225, 255, 233, 'damaged'],
#  ['p30.JPG', 342, 236, 219, 219, 'intact'],
#  ['p31.JPG', 52, 89, 174, 162, 'intact'],
#  ['p31.JPG', 213, 62, 177, 172, 'damaged'],
#  ['p31.JPG', 420, 10, 195, 201, 'intact'],
#  ['p31.JPG', 16, 258, 185, 173, 'damaged'],
#  ['p31.JPG', 204, 241, 147, 145, 'intact'],
#  ['p31.JPG', 371, 225, 164, 174, 'intact'],
#  ['p32.JPG', 37, 26, 214, 200, 'intact'],
#  ['p32.JPG', 263, 104, 158, 153, 'intact'],
#  ['p32.JPG', 418, 73, 174, 163, 'damaged'],
#  ['p32.JPG', 65, 245, 178, 179, 'intact'],
#  ['p32.JPG', 246, 262, 157, 162, 'damaged'],
#  ['p32.JPG', 399, 239, 139, 144, 'intact'],
#  ['p33.JPG', 16, 13, 220, 203, 'intact'],
#  ['p33.JPG', 241, 42, 174, 162, 'damaged'],
#  ['p33.JPG', 404, 50, 160, 162, 'intact'],
#  ['p33.JPG', 34, 223, 223, 218, 'damaged'],
#  ['p33.JPG', 266, 213, 161, 161, 'intact'],
#  ['p33.JPG', 439, 206, 187, 191, 'intact'],
#  ['p34.JPG', 41, 24, 182, 185, 'intact'],
#  ['p34.JPG', 236, 63, 154, 153, 'intact'],
#  ['p34.JPG', 415, 13, 185, 195, 'damaged'],
#  ['p34.JPG', 82, 213, 157, 161, 'intact'],
#  ['p34.JPG', 240, 214, 156, 162, 'damaged'],
#  ['p34.JPG', 412, 214, 189, 185, 'intact'],
#  ['p35.JPG', 5, 36, 204, 207, 'intact'],
#  ['p35.JPG', 221, 75, 169, 168, 'intact'],
#  ['p35.JPG', 417, 26, 219, 228, 'damaged'],
#  ['p35.JPG', 71, 236, 158, 151, 'intact'],
#  ['p35.JPG', 231, 256, 164, 159, 'damaged'],
#  ['p35.JPG', 416, 267, 207, 189, 'intact'],
#  ['p36.JPG', 80, 34, 198, 179, 'damaged'],
#  ['p36.JPG', 282, 89, 126, 121, 'intact'],
#  ['p36.JPG', 410, 56, 154, 132, 'intact'],
#  ['p36.JPG', 22, 238, 182, 175, 'intact'],
#  ['p36.JPG', 221, 226, 162, 168, 'intact'],
#  ['p36.JPG', 420, 187, 200, 197, 'intact'],
#  ['p37.JPG', 39, 43, 228, 215, 'damaged'],
#  ['p37.JPG', 275, 86, 145, 143, 'intact'],
#  ['p37.JPG', 423, 53, 172, 168, 'intact'],
#  ['p37.JPG', 16, 273, 181, 180, 'intact'],
#  ['p37.JPG', 223, 238, 165, 164, 'intact'],
#  ['p37.JPG', 426, 229, 205, 210, 'intact'],
#  ['p38.JPG', 209, 11, 133, 128, 'damaged'],
#  ['p38.JPG', 345, 52, 124, 117, 'intact'],
#  ['p38.JPG', 420, 129, 153, 141, 'intact'],
#  ['p38.JPG', 136, 145, 149, 145, 'intact'],
#  ['p38.JPG', 297, 144, 115, 118, 'intact'],
#  ['p38.JPG', 66, 294, 156, 158, 'intact'],
#  ['p38.JPG', 227, 262, 187, 190, 'damaged'],
#  ['p38.JPG', 424, 277, 188, 196, 'intact'],
#  ['p39.JPG', 84, 118, 134, 136, 'damaged'],
#  ['p39.JPG', 219, 92, 119, 111, 'intact'],
#  ['p39.JPG', 324, 5, 133, 128, 'intact'],
#  ['p39.JPG', 460, 59, 146, 147, 'intact'],
#  ['p39.JPG', 342, 148, 98, 100, 'intact'],
#  ['p39.JPG', 97, 260, 149, 151, 'intact'],
#  ['p39.JPG', 218, 189, 141, 141, 'intact'],
#  ['p39.JPG', 340, 256, 175, 178, 'damaged'],
#  ['p40.JPG', 60, 122, 137, 135, 'damaged'],
#  ['p40.JPG', 203, 93, 125, 115, 'intact'],
#  ['p40.JPG', 313, 3, 142, 135, 'intact'],
#  ['p40.JPG', 323, 153, 111, 105, 'intact'],
#  ['p40.JPG', 448, 59, 167, 165, 'intact'],
#  ['p40.JPG', 64, 266, 168, 160, 'intact'],
#  ['p40.JPG', 191, 192, 151, 155, 'intact'],
#  ['p40.JPG', 319, 266, 193, 199, 'damaged'],
#  ['p41.JPG', 111, 139, 128, 122, 'damaged'],
#  ['p41.JPG', 227, 83, 113, 113, 'intact'],
#  ['p41.JPG', 328, 4, 129, 121, 'intact'],
#  ['p41.JPG', 330, 136, 105, 103, 'intact'],
#  ['p41.JPG', 450, 141, 154, 156, 'intact'],
#  ['p41.JPG', 228, 198, 131, 129, 'intact'],
#  ['p41.JPG', 351, 263, 134, 138, 'intact'],
#  ['p41.JPG', 115, 266, 139, 144, 'intact'],
#  ['p41.JPG', 230, 337, 140, 138, 'intact'],
#  ['p42.JPG', 52, 39, 186, 184, 'damaged'],
#  ['p42.JPG', 240, 55, 182, 181, 'intact'],
#  ['p42.JPG', 432, 44, 185, 189, 'intact'],
#  ['p42.JPG', 68, 230, 194, 191, 'intact'],
#  ['p42.JPG', 270, 240, 140, 148, 'intact'],
#  ['p42.JPG', 408, 246, 203, 205, 'intact'],
#  ['p43.JPG', 84, 57, 179, 140, 'intact'],
#  ['p43.JPG', 262, 87, 134, 107, 'intact'],
#  ['p43.JPG', 400, 55, 177, 142, 'intact'],
#  ['p43.JPG', 25, 175, 210, 197, 'intact'],
#  ['p43.JPG', 245, 194, 183, 169, 'intact'],
#  ['p43.JPG', 431, 200, 202, 193, 'damaged'],
#  ['p44.JPG', 11, 34, 204, 203, 'intact'],
#  ['p44.JPG', 234, 69, 179, 170, 'intact'],
#  ['p44.JPG', 415, 45, 191, 192, 'intact'],
#  ['p44.JPG', 77, 251, 179, 180, 'intact'],
#  ['p44.JPG', 259, 243, 144, 146, 'intact'],
#  ['p44.JPG', 393, 242, 201, 206, 'damaged'],
#  ['p45.JPG', 7, 135, 178, 175, 'intact'],
#  ['p45.JPG', 180, 40, 168, 169, 'intact'],
#  ['p45.JPG', 340, 61, 174, 171, 'damaged'],
#  ['p45.JPG', 192, 214, 155, 153, 'intact'],
#  ['p45.JPG', 344, 228, 120, 124, 'intact'],
#  ['p45.JPG', 470, 197, 141, 149, 'intact'],
#  ['p46.JPG', 58, 97, 160, 153, 'intact'],
#  ['p46.JPG', 206, 28, 153, 141, 'intact'],
#  ['p46.JPG', 352, 43, 154, 151, 'damaged'],
#  ['p46.JPG', 224, 173, 138, 134, 'intact'],
#  ['p46.JPG', 362, 189, 102, 109, 'intact'],
#  ['p46.JPG', 470, 160, 131, 134, 'intact'],
#  ['p46.JPG', 75, 257, 177, 176, 'damaged'],
#  ['p47.JPG', 44, 80, 160, 151, 'intact'],
#  ['p47.JPG', 205, 108, 124, 124, 'intact'],
#  ['p47.JPG', 323, 115, 145, 151, 'intact'],
#  ['p47.JPG', 469, 20, 163, 177, 'damaged'],
#  ['p47.JPG', 475, 203, 161, 164, 'intact'],
#  ['p47.JPG', 292, 272, 170, 164, 'intact'],
#  ['p47.JPG', 118, 221, 177, 172, 'damaged'],
#  ['p48.JPG', 75, 86, 152, 149, 'intact'],
#  ['p48.JPG', 215, 17, 149, 141, 'intact'],
#  ['p48.JPG', 359, 34, 154, 149, 'damaged'],
#  ['p48.JPG', 232, 163, 130, 132, 'intact'],
#  ['p48.JPG', 365, 176, 100, 103, 'intact'],
#  ['p48.JPG', 465, 171, 139, 136, 'intact'],
#  ['p48.JPG', 89, 240, 164, 167, 'damaged'],
#  ['p48.JPG', 287, 279, 178, 174, 'damaged'],
#  ['p49.JPG', 56, 81, 181, 185, 'damaged'],
#  ['p49.JPG', 218, 21, 146, 134, 'intact'],
#  ['p49.JPG', 362, 7, 167, 148, 'intact'],
#  ['p49.JPG', 235, 164, 122, 115, 'intact'],
#  ['p49.JPG', 349, 177, 177, 168, 'damaged'],
#  ['p49.JPG', 46, 268, 154, 154, 'damaged'],
#  ['p49.JPG', 195, 277, 159, 155, 'intact'],
#  ['p49.JPG', 342, 348, 134, 129, 'intact'],
#  ['p50.JPG', 90, 61, 102, 99, 'intact'],
#  ['p50.JPG', 183, 104, 100, 101, 'intact'],
#  ['p50.JPG', 280, 100, 118, 117, 'intact'],
#  ['p50.JPG', 358, 17, 105, 100, 'intact'],
#  ['p50.JPG', 394, 119, 116, 111, 'damaged'],
#  ['p50.JPG', 503, 158, 91, 87, 'intact'],
#  ['p50.JPG', 95, 163, 106, 103, 'intact'],
#  ['p50.JPG', 214, 195, 119, 121, 'intact'],
#  ['p50.JPG', 338, 224, 84, 82, 'intact'],
#  ['p50.JPG', 423, 231, 102, 101, 'intact'],
#  ['p50.JPG', 531, 243, 97, 103, 'intact'],
#  ['p50.JPG', 129, 262, 111, 113, 'intact'],
#  ['p50.JPG', 237, 314, 100, 98, 'damaged'],
#  ['p50.JPG', 340, 315, 133, 128, 'damaged'],
#  ['p50.JPG', 490, 345, 110, 110, 'intact'],
#  ['p51.JPG', 243, 5, 115, 115, 'damaged'],
#  ['p51.JPG', 371, 35, 99, 93, 'intact'],
#  ['p51.JPG', 109, 71, 95, 93, 'intact'],
#  ['p51.JPG', 111, 169, 99, 97, 'intact'],
#  ['p51.JPG', 198, 120, 95, 96, 'intact'],
#  ['p51.JPG', 305, 120, 101, 101, 'intact'],
#  ['p51.JPG', 406, 130, 106, 110, 'damaged'],
#  ['p51.JPG', 507, 167, 80, 82, 'intact'],
#  ['p51.JPG', 144, 267, 105, 103, 'intact'],
#  ['p51.JPG', 229, 209, 115, 114, 'intact'],
#  ['p51.JPG', 351, 232, 75, 74, 'intact'],
#  ['p51.JPG', 432, 241, 94, 98, 'intact'],
#  ['p51.JPG', 147, 387, 101, 91, 'intact'],
#  ['p51.JPG', 238, 326, 100, 96, 'intact'],
#  ['p51.JPG', 338, 313, 125, 121, 'damaged'],
#  ['p51.JPG', 478, 344, 104, 104, 'intact'],
#  ['p52.JPG', 88, 132, 99, 100, 'intact'],
#  ['p52.JPG', 178, 84, 95, 96, 'intact'],
#  ['p52.JPG', 267, 130, 95, 98, 'intact'],
#  ['p52.JPG', 336, 52, 91, 91, 'intact'],
#  ['p52.JPG', 442, 42, 94, 94, 'intact'],
#  ['p52.JPG', 370, 131, 110, 104, 'intact'],
#  ['p52.JPG', 467, 133, 109, 116, 'damaged'],
#  ['p52.JPG', 3, 208, 110, 120, 'damaged'],
#  ['p52.JPG', 127, 254, 82, 83, 'intact'],
#  ['p52.JPG', 184, 186, 94, 94, 'intact'],
#  ['p52.JPG', 304, 222, 114, 112, 'intact'],
#  ['p52.JPG', 417, 240, 74, 79, 'intact'],
#  ['p52.JPG', 512, 257, 104, 105, 'intact'],
#  ['p52.JPG', 109, 348, 99, 98, 'damaged'],
#  ['p52.JPG', 215, 279, 98, 100, 'intact'],
#  ['p52.JPG', 307, 335, 99, 99, 'intact'],
#  ['p52.JPG', 407, 328, 124, 124, 'damaged'],
#  ['p52.JPG', 221, 396, 99, 83, 'intact'],
#  ['p53.JPG', 50, 15, 103, 103, 'damaged'],
#  ['p53.JPG', 216, 10, 108, 106, 'intact'],
#  ['p53.JPG', 316, 47, 97, 93, 'intact'],
#  ['p53.JPG', 416, 34, 104, 100, 'intact'],
#  ['p53.JPG', 48, 119, 104, 102, 'intact'],
#  ['p53.JPG', 149, 80, 93, 98, 'intact'],
#  ['p53.JPG', 238, 128, 102, 98, 'intact'],
#  ['p53.JPG', 344, 125, 112, 110, 'intact'],
#  ['p53.JPG', 450, 136, 112, 114, 'damaged'],
#  ['p53.JPG', 68, 219, 89, 84, 'intact'],
#  ['p53.JPG', 158, 184, 95, 96, 'intact'],
#  ['p53.JPG', 274, 221, 117, 115, 'intact'],
#  ['p53.JPG', 389, 240, 81, 82, 'intact'],
#  ['p53.JPG', 488, 263, 110, 108, 'intact'],
#  ['p53.JPG', 94, 300, 107, 104, 'intact'],
#  ['p53.JPG', 190, 288, 103, 103, 'damaged'],
#  ['p53.JPG', 276, 350, 101, 96, 'intact'],
#  ['p53.JPG', 382, 339, 118, 119, 'damaged'],
#  ['p54.JPG', 207, 18, 100, 100, 'intact'],
#  ['p54.JPG', 119, 72, 103, 100, 'damaged'],
#  ['p54.JPG', 37, 124, 96, 96, 'intact'],
#  ['p54.JPG', 308, 46, 88, 91, 'intact'],
#  ['p54.JPG', 403, 36, 98, 98, 'intact'],
#  ['p54.JPG', 230, 126, 97, 94, 'intact'],
#  ['p54.JPG', 332, 127, 105, 102, 'intact'],
#  ['p54.JPG', 430, 129, 113, 116, 'damaged'],
#  ['p54.JPG', 526, 185, 99, 99, 'intact'],
#  ['p54.JPG', 54, 222, 99, 92, 'intact'],
#  ['p54.JPG', 152, 190, 96, 93, 'intact'],
#  ['p54.JPG', 260, 218, 112, 110, 'intact'],
#  ['p54.JPG', 372, 232, 80, 81, 'intact'],
#  ['p54.JPG', 440, 251, 99, 100, 'intact'],
#  ['p54.JPG', 66, 325, 109, 104, 'intact'],
#  ['p54.JPG', 180, 284, 100, 95, 'damaged'],
#  ['p54.JPG', 194, 374, 78, 79, 'intact'],
#  ['p54.JPG', 266, 338, 94, 94, 'intact'],
#  ['p54.JPG', 366, 332, 115, 116, 'damaged'],
#  ['p55.JPG', 62, 124, 98, 100, 'intact'],
#  ['p55.JPG', 141, 87, 111, 104, 'damaged'],
#  ['p55.JPG', 246, 127, 100, 101, 'intact'],
#  ['p55.JPG', 340, 100, 93, 94, 'intact'],
#  ['p55.JPG', 418, 13, 105, 108, 'intact'],
#  ['p55.JPG', 441, 120, 120, 121, 'damaged'],
#  ['p55.JPG', 52, 227, 100, 99, 'intact'],
#  ['p55.JPG', 154, 197, 93, 90, 'intact'],
#  ['p55.JPG', 242, 232, 117, 118, 'intact'],
#  ['p55.JPG', 358, 192, 111, 108, 'intact'],
#  ['p55.JPG', 437, 253, 104, 101, 'intact'],
#  ['p55.JPG', 535, 186, 100, 109, 'intact'],
#  ['p55.JPG', 546, 322, 84, 79, 'intact'],
#  ['p55.JPG', 451, 372, 78, 81, 'intact'],
#  ['p55.JPG', 349, 334, 117, 112, 'damaged'],
#  ['p55.JPG', 248, 356, 98, 96, 'intact'],
#  ['p55.JPG', 159, 299, 104, 98, 'damaged'],
#  ['p55.JPG', 37, 339, 110, 109, 'intact'],
#  ['p56.JPG', 40, 111, 107, 101, 'intact'],
#  ['p56.JPG', 148, 91, 88, 89, 'intact'],
#  ['p56.JPG', 232, 117, 105, 97, 'intact'],
#  ['p56.JPG', 331, 90, 94, 88, 'intact'],
#  ['p56.JPG', 419, 3, 103, 99, 'intact'],
#  ['p56.JPG', 428, 117, 108, 106, 'intact'],
#  ['p56.JPG', 20, 214, 113, 104, 'intact'],
#  ['p56.JPG', 135, 186, 100, 99, 'intact'],
#  ['p56.JPG', 240, 230, 110, 104, 'damaged'],
#  ['p56.JPG', 342, 176, 119, 115, 'intact'],
#  ['p56.JPG', 518, 174, 121, 120, 'damaged'],
#  ['p56.JPG', 431, 246, 106, 112, 'intact'],
#  ['p56.JPG', 328, 301, 130, 127, 'damaged'],
#  ['p56.JPG', 139, 290, 111, 108, 'damaged'],
#  ['p56.JPG', 230, 358, 108, 103, 'intact'],
#  ['p56.JPG', 5, 336, 118, 114, 'intact'],
#  ['p57.JPG', 29, 95, 109, 106, 'intact'],
#  ['p57.JPG', 144, 80, 93, 92, 'intact'],
#  ['p57.JPG', 239, 11, 101, 101, 'intact'],
#  ['p57.JPG', 237, 108, 108, 107, 'intact'],
#  ['p57.JPG', 345, 59, 105, 106, 'intact'],
#  ['p57.JPG', 437, 90, 109, 117, 'damaged'],
#  ['p57.JPG', 528, 157, 108, 124, 'damaged'],
#  ['p57.JPG', 15, 202, 118, 112, 'intact'],
#  ['p57.JPG', 134, 177, 107, 102, 'intact'],
#  ['p57.JPG', 247, 223, 110, 107, 'damaged'],
#  ['p57.JPG', 351, 172, 119, 116, 'intact'],
#  ['p57.JPG', 434, 240, 107, 109, 'intact'],
#  ['p57.JPG', 141, 285, 114, 109, 'damaged'],
#  ['p57.JPG', 4, 327, 123, 122, 'intact'],
#  ['p57.JPG', 234, 349, 112, 104, 'intact'],
#  ['p57.JPG', 336, 298, 128, 129, 'damaged'],
#  ['p58.JPG', 47, 131, 102, 99, 'intact'],
#  ['p58.JPG', 152, 111, 86, 82, 'intact'],
#  ['p58.JPG', 238, 48, 94, 90, 'intact'],
#  ['p58.JPG', 238, 137, 100, 99, 'intact'],
#  ['p58.JPG', 335, 86, 100, 102, 'intact'],
#  ['p58.JPG', 421, 115, 103, 108, 'intact'],
#  ['p58.JPG', 512, 159, 116, 121, 'damaged'],
#  ['p58.JPG', 10, 238, 116, 111, 'intact'],
#  ['p58.JPG', 142, 197, 99, 98, 'intact'],
#  ['p58.JPG', 66, 341, 106, 101, 'intact'],
#  ['p58.JPG', 157, 293, 104, 100, 'intact'],
#  ['p58.JPG', 242, 355, 102, 103, 'damaged'],
#  ['p58.JPG', 342, 306, 117, 120, 'damaged'],
#  ['p58.JPG', 248, 243, 101, 103, 'damaged'],
#  ['p58.JPG', 349, 186, 105, 111, 'intact'],
#  ['p58.JPG', 434, 234, 104, 110, 'damaged'],
#  ['p59.JPG', 54, 90, 127, 125, 'damaged'],
#  ['p59.JPG', 176, 102, 94, 90, 'intact'],
#  ['p59.JPG', 254, 40, 99, 99, 'intact'],
#  ['p59.JPG', 354, 84, 102, 103, 'intact'],
#  ['p59.JPG', 440, 121, 100, 108, 'intact'],
#  ['p59.JPG', 549, 194, 89, 93, 'intact'],
#  ['p59.JPG', 11, 218, 146, 128, 'intact'],
#  ['p59.JPG', 156, 197, 99, 91, 'intact'],
#  ['p59.JPG', 260, 135, 103, 103, 'intact'],
#  ['p59.JPG', 357, 192, 113, 112, 'intact'],
#  ['p59.JPG', 440, 247, 105, 104, 'damaged'],
#  ['p59.JPG', 261, 243, 106, 105, 'damaged'],
#  ['p59.JPG', 352, 309, 118, 123, 'damaged'],
#  ['p59.JPG', 249, 351, 101, 102, 'damaged'],
#  ['p59.JPG', 166, 290, 105, 100, 'intact'],
#  ['p59.JPG', 76, 345, 104, 100, 'intact'],
#  ['p60.JPG', 85, 25, 141, 145, 'damaged'],
#  ['p60.JPG', 234, 22, 99, 97, 'intact'],
#  ['p60.JPG', 332, 24, 104, 109, 'intact'],
#  ['p60.JPG', 421, 57, 110, 109, 'intact'],
#  ['p60.JPG', 96, 169, 124, 120, 'damaged'],
#  ['p60.JPG', 217, 111, 85, 86, 'intact'],
#  ['p60.JPG', 303, 133, 99, 98, 'intact'],
#  ['p60.JPG', 401, 169, 115, 107, 'intact'],
#  ['p60.JPG', 502, 149, 100, 101, 'damaged'],
#  ['p60.JPG', 219, 203, 99, 95, 'intact'],
#  ['p60.JPG', 317, 232, 99, 104, 'damaged'],
#  ['p60.JPG', 415, 285, 113, 121, 'damaged'],
#  ['p60.JPG', 522, 263, 97, 103, 'damaged'],
#  ['p60.JPG', 87, 296, 111, 103, 'intact'],
#  ['p60.JPG', 213, 301, 106, 103, 'intact'],
#  ['p60.JPG', 315, 337, 99, 105, 'damaged'],
#  ['p61.JPG', 47, 77, 94, 92, 'intact'],
#  ['p61.JPG', 130, 17, 93, 97, 'intact'],
#  ['p61.JPG', 211, 12, 111, 116, 'intact'],
#  ['p61.JPG', 322, 5, 113, 118, 'intact'],
#  ['p61.JPG', 460, 53, 117, 111, 'damaged'],
#  ['p61.JPG', 130, 116, 109, 102, 'intact'],
#  ['p61.JPG', 239, 127, 131, 126, 'damaged'],
#  ['p61.JPG', 379, 113, 115, 114, 'intact'],
#  ['p61.JPG', 492, 169, 103, 109, 'damaged'],
#  ['p61.JPG', 27, 192, 148, 136, 'damaged'],
#  ['p61.JPG', 178, 235, 101, 101, 'intact'],
#  ['p61.JPG', 268, 264, 109, 109, 'damaged'],
#  ['p61.JPG', 381, 233, 126, 129, 'damaged'],
#  ['p61.JPG', 498, 305, 115, 114, 'intact'],
#  ['p61.JPG', 59, 331, 108, 107, 'intact'],
#  ['p61.JPG', 172, 342, 106, 102, 'intact'],
#  ['p61.JPG', 272, 376, 106, 103, 'damaged'],
#  ['p61.JPG', 378, 351, 96, 100, 'intact'],
#  ['p62.JPG', 21, 32, 109, 114, 'damaged'],
#  ['p62.JPG', 139, 70, 101, 108, 'intact'],
#  ['p62.JPG', 235, 43, 114, 115, 'intact'],
#  ['p62.JPG', 347, 90, 108, 103, 'intact'],
#  ['p62.JPG', 475, 109, 92, 88, 'intact'],
#  ['p62.JPG', 2, 147, 90, 115, 'intact'],
#  ['p62.JPG', 98, 181, 120, 122, 'damaged'],
#  ['p62.JPG', 234, 163, 110, 107, 'damaged'],
#  ['p62.JPG', 357, 195, 114, 110, 'intact'],
#  ['p62.JPG', 487, 195, 146, 144, 'intact'],
#  ['p62.JPG', 25, 267, 103, 100, 'damaged'],
#  ['p62.JPG', 142, 308, 110, 109, 'intact'],
#  ['p62.JPG', 263, 258, 123, 123, 'damaged'],
#  ['p62.JPG', 400, 290, 106, 102, 'intact'],
#  ['p62.JPG', 483, 333, 95, 88, 'intact'],
#  ['p62.JPG', 72, 364, 111, 97, 'damaged'],
#  ['p62.JPG', 235, 370, 111, 103, 'intact'],
#  ['p62.JPG', 343, 381, 108, 96, 'intact'],
#  ['p63.JPG', 14, 93, 138, 133, 'intact'],
#  ['p63.JPG', 172, 95, 138, 125, 'intact'],
#  ['p63.JPG', 317, 108, 136, 138, 'intact'],
#  ['p63.JPG', 467, 59, 168, 169, 'damaged'],
#  ['p63.JPG', 51, 232, 131, 129, 'intact'],
#  ['p63.JPG', 176, 228, 146, 153, 'intact'],
#  ['p63.JPG', 326, 253, 128, 133, 'intact'],
#  ['p63.JPG', 449, 234, 141, 145, 'intact'],
#  ['p64.JPG', 30, 55, 165, 162, 'damaged'],
#  ['p64.JPG', 203, 81, 120, 120, 'intact'],
#  ['p64.JPG', 318, 78, 143, 138, 'intact'],
#  ['p64.JPG', 451, 97, 118, 124, 'intact'],
#  ['p64.JPG', 57, 220, 142, 140, 'intact'],
#  ['p64.JPG', 205, 217, 132, 137, 'intact'],
#  ['p64.JPG', 345, 223, 122, 126, 'intact'],
#  ['p64.JPG', 472, 227, 105, 110, 'intact'],
#  ['p65.JPG', 53, 3, 173, 168, 'damaged'],
#  ['p65.JPG', 232, 44, 128, 134, 'intact'],
#  ['p65.JPG', 362, 48, 146, 142, 'intact'],
#  ['p65.JPG', 496, 69, 128, 135, 'intact'],
#  ['p65.JPG', 93, 192, 115, 109, 'intact'],
#  ['p65.JPG', 230, 205, 139, 141, 'damaged'],
#  ['p65.JPG', 378, 197, 139, 132, 'intact'],
#  ['p65.JPG', 518, 214, 112, 115, 'intact'],
#  ['p65.JPG', 107, 312, 142, 142, 'intact'],
#  ['p65.JPG', 333, 316, 121, 126, 'intact'],
#  ['p66.JPG', 114, 68, 108, 106, 'intact'],
#  ['p66.JPG', 228, 51, 119, 113, 'damaged'],
#  ['p66.JPG', 363, 28, 106, 107, 'intact'],
#  ['p66.JPG', 175, 153, 126, 123, 'intact'],
#  ['p66.JPG', 309, 142, 129, 134, 'damaged'],
#  ['p66.JPG', 443, 96, 126, 132, 'intact'],
#  ['p66.JPG', 77, 233, 119, 123, 'intact'],
#  ['p66.JPG', 188, 272, 135, 135, 'intact'],
#  ['p66.JPG', 323, 289, 121, 127, 'intact'],
#  ['p66.JPG', 445, 253, 166, 166, 'damaged'],
#  ['p67.JPG', 12, 28, 174, 167, 'damaged'],
#  ['p67.JPG', 193, 49, 123, 125, 'intact'],
#  ['p67.JPG', 317, 75, 142, 137, 'intact'],
#  ['p67.JPG', 441, 135, 125, 124, 'intact'],
#  ['p67.JPG', 41, 221, 142, 141, 'damaged'],
#  ['p67.JPG', 182, 201, 133, 131, 'intact'],
#  ['p67.JPG', 325, 210, 136, 135, 'intact'],
#  ['p67.JPG', 493, 252, 139, 139, 'intact'],
#  ['p67.JPG', 129, 363, 119, 113, 'intact'],
#  ['p67.JPG', 267, 333, 126, 128, 'damaged'],
#  ['p67.JPG', 402, 333, 111, 119, 'intact'],
#  ['p68.JPG', 119, 73, 127, 121, 'damaged'],
#  ['p68.JPG', 10, 150, 122, 120, 'intact'],
#  ['p68.JPG', 121, 222, 113, 113, 'intact'],
#  ['p68.JPG', 214, 146, 112, 112, 'intact'],
#  ['p68.JPG', 258, 51, 101, 98, 'intact'],
#  ['p68.JPG', 372, 53, 98, 94, 'intact'],
#  ['p68.JPG', 335, 153, 113, 112, 'intact'],
#  ['p68.JPG', 449, 142, 98, 103, 'damaged'],
#  ['p68.JPG', 222, 259, 122, 121, 'intact'],
#  ['p68.JPG', 347, 274, 106, 116, 'intact'],
#  ['p68.JPG', 456, 241, 156, 151, 'damaged'],
#  ['p69.JPG', 6, 95, 112, 113, 'intact'],
#  ['p69.JPG', 142, 125, 130, 124, 'damaged'],
#  ['p69.JPG', 225, 46, 101, 99, 'intact'],
#  ['p69.JPG', 330, 56, 100, 98, 'intact'],
#  ['p69.JPG', 474, 69, 108, 102, 'intact'],
#  ['p69.JPG', 66, 215, 98, 94, 'damaged'],
#  ['p69.JPG', 163, 254, 112, 114, 'damaged'],
#  ['p69.JPG', 282, 238, 95, 95, 'intact'],
#  ['p69.JPG', 277, 143, 88, 91, 'intact'],
#  ['p69.JPG', 371, 147, 103, 99, 'intact'],
#  ['p69.JPG', 461, 191, 92, 92, 'intact'],
#  ['p69.JPG', 553, 153, 78, 79, 'intact'],
#  ['p69.JPG', 102, 312, 85, 89, 'damaged'],
#  ['p69.JPG', 167, 365, 98, 94, 'intact'],
#  ['p69.JPG', 260, 337, 81, 79, 'intact'],
#  ['p69.JPG', 342, 336, 103, 102, 'intact'],
#  ['p69.JPG', 377, 248, 98, 88, 'intact'],
#  ['p69.JPG', 448, 301, 105, 104, 'damaged'],
#  ['p70.JPG', 6, 58, 116, 121, 'intact'],
#  ['p70.JPG', 132, 2, 100, 95, 'intact'],
#  ['p70.JPG', 238, 2, 107, 110, 'intact'],
#  ['p70.JPG', 349, 13, 105, 106, 'intact'],
#  ['p70.JPG', 484, 25, 119, 116, 'intact'],
#  ['p70.JPG', 143, 91, 137, 132, 'damaged'],
#  ['p70.JPG', 284, 104, 95, 100, 'intact'],
#  ['p70.JPG', 384, 116, 100, 101, 'intact'],
#  ['p70.JPG', 488, 171, 118, 115, 'intact'],
#  ['p70.JPG', 67, 185, 104, 98, 'damaged'],
#  ['p70.JPG', 161, 232, 116, 114, 'damaged'],
#  ['p70.JPG', 303, 210, 82, 83, 'intact'],
#  ['p70.JPG', 388, 220, 94, 96, 'intact'],
#  ['p70.JPG', 105, 287, 90, 87, 'damaged'],
#  ['p70.JPG', 167, 343, 102, 99, 'intact'],
#  ['p70.JPG', 274, 291, 103, 108, 'intact'],
#  ['p70.JPG', 384, 322, 97, 96, 'intact'],
#  ['p70.JPG', 476, 284, 108, 105, 'damaged'],
#  ['p71.JPG', 79, 11, 100, 94, 'intact'],
#  ['p71.JPG', 181, 14, 107, 100, 'intact'],
#  ['p71.JPG', 291, 21, 103, 100, 'intact'],
#  ['p71.JPG', 424, 27, 116, 109, 'intact'],
#  ['p71.JPG', 81, 100, 139, 135, 'damaged'],
#  ['p71.JPG', 228, 114, 98, 95, 'intact'],
#  ['p71.JPG', 332, 117, 100, 98, 'intact'],
#  ['p71.JPG', 430, 154, 116, 118, 'intact'],
#  ['p71.JPG', 533, 215, 104, 106, 'damaged'],
#  ['p71.JPG', 2, 213, 123, 122, 'damaged'],
#  ['p71.JPG', 156, 222, 97, 100, 'damaged'],
#  ['p71.JPG', 255, 214, 83, 84, 'intact'],
#  ['p71.JPG', 339, 226, 97, 102, 'intact'],
#  ['p71.JPG', 432, 287, 114, 114, 'damaged'],
#  ['p71.JPG', 337, 331, 104, 102, 'intact'],
#  ['p71.JPG', 223, 304, 110, 114, 'intact'],
#  ['p71.JPG', 106, 338, 109, 108, 'intact'],
#  ['p71.JPG', 518, 107, 77, 85, 'intact'],
#  ['p72.JPG', 86, 60, 112, 114, 'damaged'],
#  ['p72.JPG', 190, 30, 104, 101, 'intact'],
#  ['p72.JPG', 300, 53, 103, 106, 'intact'],
#  ['p72.JPG', 411, 16, 107, 106, 'intact'],
#  ['p72.JPG', 55, 174, 122, 117, 'intact'],
#  ['p72.JPG', 198, 133, 100, 101, 'intact'],
#  ['p72.JPG', 299, 157, 84, 84, 'intact'],
#  ['p72.JPG', 396, 134, 105, 103, 'damaged'],
#  ['p72.JPG', 490, 137, 85, 95, 'damaged'],
#  ['p72.JPG', 109, 297, 101, 103, 'intact'],
#  ['p72.JPG', 194, 238, 98, 100, 'intact'],
#  ['p72.JPG', 294, 241, 103, 101, 'damaged'],
#  ['p72.JPG', 407, 240, 103, 103, 'intact'],
#  ['p72.JPG', 329, 335, 134, 130, 'damaged'],
#  ['p72.JPG', 458, 358, 94, 97, 'intact'],
#  ['p73.JPG', 96, 63, 114, 114, 'damaged'],
#  ['p73.JPG', 200, 29, 104, 101, 'intact'],
#  ['p73.JPG', 308, 10, 120, 123, 'damaged'],
#  ['p73.JPG', 431, 15, 99, 105, 'intact'],
#  ['p73.JPG', 210, 132, 98, 100, 'intact'],
#  ['p73.JPG', 313, 139, 102, 103, 'damaged'],
#  ['p73.JPG', 419, 132, 99, 101, 'damaged'],
#  ['p73.JPG', 504, 133, 83, 94, 'damaged'],
#  ['p73.JPG', 72, 177, 121, 116, 'intact'],
#  ['p73.JPG', 206, 234, 86, 86, 'intact'],
#  ['p73.JPG', 304, 244, 100, 96, 'intact'],
#  ['p73.JPG', 426, 238, 100, 101, 'intact'],
#  ['p73.JPG', 100, 289, 134, 136, 'damaged'],
#  ['p73.JPG', 236, 333, 104, 104, 'intact'],
#  ['p73.JPG', 360, 331, 93, 100, 'intact'],
#  ['p73.JPG', 458, 333, 96, 99, 'intact'],
#  ['p74.JPG', 158, 32, 114, 108, 'intact'],
#  ['p74.JPG', 273, 2, 136, 132, 'damaged'],
#  ['p74.JPG', 410, 23, 108, 114, 'intact'],
#  ['p74.JPG', 6, 196, 138, 134, 'intact'],
#  ['p74.JPG', 159, 146, 112, 111, 'intact'],
#  ['p74.JPG', 274, 149, 111, 113, 'damaged'],
#  ['p74.JPG', 394, 142, 115, 114, 'damaged'],
#  ['p74.JPG', 496, 107, 100, 102, 'damaged'],
#  ['p74.JPG', 160, 260, 102, 97, 'intact'],
#  ['p74.JPG', 272, 265, 112, 109, 'intact'],
#  ['p74.JPG', 391, 259, 116, 117, 'intact'],
#  ['p74.JPG', 508, 220, 125, 135, 'damaged'],
#  ['p74.JPG', 42, 331, 154, 146, 'damaged'],
#  ['p74.JPG', 199, 369, 118, 110, 'intact'],
#  ['p74.JPG', 339, 359, 108, 111, 'intact'],
#  ['p74.JPG', 457, 357, 100, 108, 'intact'],
#  ['p75.JPG', 99, 47, 104, 100, 'intact'],
#  ['p75.JPG', 222, 39, 99, 99, 'intact'],
#  ['p75.JPG', 344, 33, 105, 109, 'intact'],
#  ['p75.JPG', 449, 44, 137, 135, 'intact'],
#  ['p75.JPG', 74, 180, 103, 104, 'damaged'],
#  ['p75.JPG', 164, 123, 104, 106, 'intact'],
#  ['p75.JPG', 276, 130, 100, 97, 'intact'],
#  ['p75.JPG', 385, 150, 88, 84, 'intact'],
#  ['p75.JPG', 487, 182, 115, 113, 'intact'],
#  ['p75.JPG', 163, 235, 106, 102, 'damaged'],
#  ['p75.JPG', 271, 231, 103, 101, 'damaged'],
#  ['p75.JPG', 373, 238, 97, 96, 'intact'],
#  ['p75.JPG', 467, 299, 126, 118, 'damaged'],
#  ['p75.JPG', 356, 352, 124, 118, 'damaged'],
#  ['p75.JPG', 254, 350, 97, 99, 'intact'],
#  ['p75.JPG', 110, 333, 105, 102, 'intact'],
#  ['p76.JPG', 80, 68, 130, 128, 'damaged'],
#  ['p76.JPG', 196, 11, 127, 131, 'damaged'],
#  ['p76.JPG', 326, 22, 102, 102, 'intact'],
#  ['p76.JPG', 435, 11, 111, 107, 'intact'],
#  ['p76.JPG', 115, 212, 102, 102, 'intact'],
#  ['p76.JPG', 217, 153, 94, 97, 'intact'],
#  ['p76.JPG', 312, 132, 105, 108, 'damaged'],
#  ['p76.JPG', 419, 118, 108, 108, 'damaged'],
#  ['p76.JPG', 522, 108, 83, 89, 'intact'],
#  ['p76.JPG', 269, 235, 116, 116, 'intact'],
#  ['p76.JPG', 392, 239, 108, 108, 'intact'],
#  ['p76.JPG', 491, 204, 93, 95, 'intact'],
#  ['p76.JPG', 475, 304, 105, 101, 'damaged'],
#  ['p76.JPG', 360, 356, 105, 101, 'damaged'],
#  ['p76.JPG', 252, 354, 103, 103, 'intact'],
#  ['p76.JPG', 115, 319, 133, 134, 'damaged'],
#  ['p77.JPG', 168, 25, 127, 128, 'damaged'],
#  ['p77.JPG', 49, 76, 133, 128, 'damaged'],
#  ['p77.JPG', 297, 39, 100, 101, 'intact'],
#  ['p77.JPG', 423, 5, 102, 104, 'intact'],
#  ['p77.JPG', 82, 211, 105, 102, 'damaged'],
#  ['p77.JPG', 177, 164, 93, 96, 'intact'],
#  ['p77.JPG', 273, 145, 98, 102, 'damaged'],
#  ['p77.JPG', 384, 116, 127, 126, 'damaged'],
#  ['p77.JPG', 510, 137, 74, 83, 'intact'],
#  ['p77.JPG', 240, 250, 111, 108, 'intact'],
#  ['p77.JPG', 355, 252, 99, 99, 'intact'],
#  ['p77.JPG', 476, 228, 90, 94, 'intact'],
#  ['p77.JPG', 439, 330, 95, 96, 'damaged'],
#  ['p77.JPG', 326, 361, 97, 94, 'damaged'],
#  ['p77.JPG', 219, 363, 100, 95, 'intact'],
#  ['p77.JPG', 96, 323, 100, 100, 'intact'],
#  ['p78.JPG', 39, 75, 130, 130, 'damaged'],
#  ['p78.JPG', 161, 24, 127, 127, 'damaged'],
#  ['p78.JPG', 296, 43, 101, 101, 'intact'],
#  ['p78.JPG', 419, 2, 104, 104, 'intact'],
#  ['p78.JPG', 515, 35, 95, 100, 'intact'],
#  ['p78.JPG', 165, 167, 101, 96, 'intact'],
#  ['p78.JPG', 270, 147, 102, 100, 'damaged'],
#  ['p78.JPG', 377, 114, 133, 135, 'damaged'],
#  ['p78.JPG', 508, 139, 81, 85, 'intact'],
#  ['p78.JPG', 58, 216, 111, 110, 'damaged'],
#  ['p78.JPG', 235, 250, 112, 114, 'intact'],
#  ['p78.JPG', 351, 253, 103, 104, 'intact'],
#  ['p78.JPG', 441, 326, 96, 101, 'damaged'],
#  ['p78.JPG', 326, 365, 100, 100, 'damaged'],
#  ['p78.JPG', 210, 364, 102, 101, 'intact'],
#  ['p78.JPG', 102, 329, 112, 111, 'intact'],
#  ['p79.JPG', 53, 68, 128, 127, 'damaged'],
#  ['p79.JPG', 167, 7, 128, 123, 'damaged'],
#  ['p79.JPG', 300, 31, 101, 98, 'intact'],
#  ['p79.JPG', 403, 24, 105, 104, 'intact'],
#  ['p79.JPG', 505, 19, 95, 104, 'intact'],
#  ['p79.JPG', 174, 148, 100, 95, 'intact'],
#  ['p79.JPG', 279, 131, 106, 101, 'damaged'],
#  ['p79.JPG', 381, 144, 95, 94, 'intact'],
#  ['p79.JPG', 481, 119, 79, 83, 'intact'],
#  ['p79.JPG', 73, 201, 105, 103, 'damaged'],
#  ['p79.JPG', 236, 231, 115, 111, 'intact'],
#  ['p79.JPG', 354, 239, 104, 103, 'intact'],
#  ['p79.JPG', 469, 203, 133, 134, 'damaged'],
#  ['p79.JPG', 114, 304, 107, 105, 'intact'],
#  ['p79.JPG', 210, 343, 105, 103, 'intact'],
#  ['p79.JPG', 320, 348, 102, 98, 'damaged'],
#  ['p79.JPG', 424, 319, 101, 105, 'damaged'],
#  ['p80.JPG', 17, 28, 134, 136, 'damaged'],
#  ['p80.JPG', 148, 58, 107, 102, 'damaged'],
#  ['p80.JPG', 250, 33, 105, 108, 'damaged'],
#  ['p80.JPG', 358, 42, 103, 103, 'intact'],
#  ['p80.JPG', 473, 30, 120, 121, 'damaged'],
#  ['p80.JPG', 93, 154, 121, 119, 'damaged'],
#  ['p80.JPG', 216, 140, 103, 105, 'intact'],
#  ['p80.JPG', 322, 143, 110, 111, 'intact'],
#  ['p80.JPG', 117, 276, 83, 84, 'intact'],
#  ['p80.JPG', 202, 247, 91, 86, 'intact'],
#  ['p80.JPG', 295, 275, 92, 92, 'intact'],
#  ['p80.JPG', 395, 237, 92, 93, 'intact'],
#  ['p80.JPG', 489, 180, 101, 101, 'damaged'],
#  ['p80.JPG', 490, 289, 119, 118, 'damaged'],
#  ['p80.JPG', 364, 334, 106, 102, 'intact'],
#  ['p80.JPG', 265, 373, 97, 95, 'damaged'],
#  ['p80.JPG', 167, 347, 101, 100, 'intact'],
#  ['p80.JPG', 70, 352, 101, 98, 'intact'],
#  ['p81.JPG', 24, 28, 119, 118, 'damaged'],
#  ['p81.JPG', 146, 40, 94, 95, 'damaged'],
#  ['p81.JPG', 245, 29, 95, 94, 'damaged'],
#  ['p81.JPG', 356, 17, 107, 109, 'damaged'],
#  ['p81.JPG', 464, 39, 90, 93, 'intact'],
#  ['p81.JPG', 105, 142, 109, 111, 'damaged'],
#  ['p81.JPG', 210, 128, 96, 95, 'intact'],
#  ['p81.JPG', 311, 132, 100, 104, 'intact'],
#  ['p81.JPG', 425, 145, 102, 98, 'intact'],
#  ['p81.JPG', 548, 115, 90, 88, 'damaged'],
#  ['p81.JPG', 3, 233, 91, 98, 'intact'],
#  ['p81.JPG', 123, 261, 75, 75, 'intact'],
#  ['p81.JPG', 201, 230, 87, 84, 'intact'],
#  ['p81.JPG', 291, 264, 85, 88, 'intact'],
#  ['p81.JPG', 375, 227, 87, 85, 'intact'],
#  ['p81.JPG', 78, 333, 92, 88, 'intact'],
#  ['p81.JPG', 167, 318, 94, 95, 'intact'],
#  ['p81.JPG', 255, 350, 92, 88, 'damaged'],
#  ['p81.JPG', 355, 321, 101, 96, 'intact'],
#  ['p81.JPG', 458, 271, 117, 113, 'damaged'],
#  ['p82.JPG', 72, 62, 150, 143, 'damaged'],
#  ['p82.JPG', 241, 88, 144, 138, 'damaged'],
#  ['p82.JPG', 435, 95, 129, 128, 'intact'],
#  ['p82.JPG', 84, 226, 158, 162, 'damaged'],
#  ['p82.JPG', 247, 238, 166, 170, 'damaged'],
#  ['p82.JPG', 427, 236, 163, 162, 'damaged'],
#  ['p83.JPG', 86, 56, 103, 102, 'intact'],
#  ['p83.JPG', 215, 60, 127, 128, 'damaged'],
#  ['p83.JPG', 357, 57, 123, 123, 'damaged'],
#  ['p83.JPG', 468, 81, 121, 122, 'damaged'],
#  ['p83.JPG', 108, 190, 98, 99, 'damaged'],
#  ['p83.JPG', 223, 195, 106, 101, 'intact'],
#  ['p83.JPG', 363, 194, 111, 104, 'damaged'],
#  ['p83.JPG', 489, 213, 110, 106, 'damaged'],
#  ['p83.JPG', 85, 311, 108, 107, 'damaged'],
#  ['p83.JPG', 212, 315, 109, 111, 'intact'],
#  ['p83.JPG', 343, 319, 111, 111, 'intact'],
#  ['p83.JPG', 507, 346, 115, 121, 'intact'],
#  ['p84.JPG', 40, 6, 123, 119, 'intact'],
#  ['p84.JPG', 204, 39, 109, 109, 'intact'],
#  ['p84.JPG', 336, 56, 99, 100, 'intact'],
#  ['p84.JPG', 464, 48, 96, 104, 'damaged'],
#  ['p84.JPG', 81, 140, 110, 108, 'damaged'],
#  ['p84.JPG', 214, 154, 104, 106, 'damaged'],
#  ['p84.JPG', 341, 169, 102, 103, 'damaged'],
#  ['p84.JPG', 460, 178, 89, 92, 'damaged'],
#  ['p84.JPG', 36, 272, 130, 128, 'damaged'],
#  ['p84.JPG', 198, 271, 126, 121, 'damaged'],
#  ['p84.JPG', 336, 280, 118, 122, 'damaged'],
#  ['p84.JPG', 469, 285, 100, 100, 'intact'],
#  ['p85.JPG', 32, 4, 121, 117, 'intact'],
#  ['p85.JPG', 187, 27, 108, 108, 'intact'],
#  ['p85.JPG', 301, 46, 119, 124, 'damaged'],
#  ['p85.JPG', 434, 69, 93, 99, 'damaged'],
#  ['p85.JPG', 539, 138, 94, 106, 'intact'],
#  ['p85.JPG', 57, 144, 107, 102, 'damaged'],
#  ['p85.JPG', 190, 165, 106, 103, 'damaged'],
#  ['p85.JPG', 309, 179, 96, 94, 'intact'],
#  ['p85.JPG', 410, 188, 87, 86, 'damaged'],
#  ['p85.JPG', 520, 260, 89, 89, 'intact'],
#  ['p85.JPG', 27, 277, 126, 122, 'damaged'],
#  ['p85.JPG', 173, 295, 102, 103, 'damaged'],
#  ['p85.JPG', 300, 286, 111, 116, 'damaged'],
#  ['p85.JPG', 426, 301, 94, 88, 'intact'],
#  ['p86.JPG', 14, 14, 120, 113, 'intact'],
#  ['p86.JPG', 176, 34, 99, 99, 'intact'],
#  ['p86.JPG', 291, 45, 99, 98, 'damaged'],
#  ['p86.JPG', 421, 72, 96, 97, 'damaged'],
#  ['p86.JPG', 533, 138, 96, 104, 'damaged'],
#  ['p86.JPG', 90, 164, 93, 87, 'intact'],
#  ['p86.JPG', 216, 166, 98, 93, 'intact'],
#  ['p86.JPG', 326, 183, 84, 85, 'damaged'],
#  ['p86.JPG', 439, 194, 82, 90, 'intact'],
#  ['p86.JPG', 18, 287, 127, 125, 'damaged'],
#  ['p86.JPG', 167, 295, 100, 108, 'damaged'],
#  ['p86.JPG', 280, 294, 117, 124, 'damaged'],
#  ['p86.JPG', 410, 305, 94, 95, 'intact'],
#  ['p86.JPG', 548, 292, 85, 95, 'damaged'],
#  ['p87.JPG', 19, 26, 112, 108, 'intact'],
#  ['p87.JPG', 160, 49, 103, 101, 'intact'],
#  ['p87.JPG', 281, 63, 103, 100, 'damaged'],
#  ['p87.JPG', 397, 83, 90, 92, 'intact'],
#  ['p87.JPG', 503, 44, 81, 81, 'intact'],
#  ['p87.JPG', 521, 140, 101, 107, 'intact'],
#  ['p87.JPG', 404, 194, 99, 97, 'damaged'],
#  ['p87.JPG', 71, 165, 97, 95, 'intact'],
#  ['p87.JPG', 202, 161, 93, 97, 'intact'],
#  ['p87.JPG', 308, 177, 88, 88, 'damaged'],
#  ['p87.JPG', 394, 299, 95, 96, 'intact'],
#  ['p87.JPG', 263, 279, 120, 121, 'damaged'],
#  ['p87.JPG', 148, 291, 100, 102, 'damaged'],
#  ['p87.JPG', 10, 285, 118, 117, 'damaged'],
#  ['p87.JPG', 522, 264, 93, 98, 'damaged'],
#  ['p88.JPG', 32, 46, 113, 112, 'intact'],
#  ['p88.JPG', 178, 68, 106, 101, 'intact'],
#  ['p88.JPG', 289, 44, 128, 136, 'damaged'],
#  ['p88.JPG', 419, 100, 91, 96, 'intact'],
#  ['p88.JPG', 532, 69, 84, 85, 'intact'],
#  ['p88.JPG', 40, 185, 97, 94, 'intact'],
#  ['p88.JPG', 178, 191, 97, 94, 'intact'],
#  ['p88.JPG', 288, 192, 90, 90, 'damaged'],
#  ['p88.JPG', 424, 217, 100, 98, 'damaged'],
#  ['p88.JPG', 527, 176, 95, 93, 'damaged'],
#  ['p88.JPG', 13, 301, 123, 113, 'damaged'],
#  ['p88.JPG', 162, 310, 104, 99, 'damaged'],
#  ['p88.JPG', 291, 313, 119, 114, 'damaged'],
#  ['p88.JPG', 419, 318, 94, 94, 'intact'],
#  ['p88.JPG', 540, 279, 95, 99, 'damaged'],
#  ['p89.JPG', 21, 26, 124, 119, 'damaged'],
#  ['p89.JPG', 175, 62, 97, 98, 'intact'],
#  ['p89.JPG', 284, 32, 130, 133, 'damaged'],
#  ['p89.JPG', 414, 83, 90, 97, 'intact'],
#  ['p89.JPG', 526, 49, 85, 86, 'intact'],
#  ['p89.JPG', 534, 156, 88, 98, 'damaged'],
#  ['p89.JPG', 421, 190, 100, 102, 'damaged'],
#  ['p89.JPG', 291, 182, 93, 90, 'damaged'],
#  ['p89.JPG', 154, 181, 101, 101, 'intact'],
#  ['p89.JPG', 35, 176, 96, 98, 'intact'],
#  ['p89.JPG', 3, 308, 107, 106, 'intact'],
#  ['p89.JPG', 157, 291, 104, 102, 'damaged'],
#  ['p89.JPG', 277, 290, 121, 123, 'damaged'],
#  ['p89.JPG', 417, 302, 98, 100, 'intact'],
#  ['p89.JPG', 540, 269, 94, 103, 'damaged'],
#  ['p90.JPG', 20, 8, 134, 129, 'damaged'],
#  ['p90.JPG', 181, 40, 104, 103, 'intact'],
#  ['p90.JPG', 294, 7, 135, 138, 'damaged'],
#  ['p90.JPG', 425, 36, 100, 101, 'intact'],
#  ['p90.JPG', 37, 169, 103, 103, 'intact'],
#  ['p90.JPG', 174, 164, 96, 98, 'damaged'],
#  ['p90.JPG', 292, 162, 107, 106, 'intact'],
#  ['p90.JPG', 419, 174, 102, 105, 'damaged'],
#  ['p90.JPG', 527, 123, 83, 84, 'intact'],
#  ['p90.JPG', 5, 310, 120, 113, 'intact'],
#  ['p90.JPG', 162, 308, 106, 113, 'damaged'],
#  ['p90.JPG', 289, 287, 127, 128, 'damaged'],
#  ['p90.JPG', 425, 298, 100, 103, 'intact'],
#  ['p90.JPG', 535, 254, 97, 104, 'damaged'],
#  ['p91.JPG', 25, 37, 121, 127, 'damaged'],
#  ['p91.JPG', 195, 75, 96, 98, 'damaged'],
#  ['p91.JPG', 306, 15, 134, 140, 'damaged'],
#  ['p91.JPG', 450, 49, 96, 103, 'intact'],
#  ['p91.JPG', 551, 124, 85, 86, 'intact'],
#  ['p91.JPG', 9, 187, 114, 113, 'intact'],
#  ['p91.JPG', 176, 186, 102, 99, 'intact'],
#  ['p91.JPG', 294, 185, 109, 105, 'intact'],
#  ['p91.JPG', 416, 171, 103, 106, 'damaged'],
#  ['p91.JPG', 532, 226, 96, 105, 'damaged'],
#  ['p91.JPG', 57, 301, 101, 93, 'intact'],
#  ['p91.JPG', 168, 303, 99, 100, 'damaged'],
#  ['p91.JPG', 281, 296, 120, 123, 'damaged'],
#  ['p91.JPG', 412, 291, 101, 99, 'intact'],
#  ['p92.JPG', 11, 68, 113, 109, 'intact'],
#  ['p92.JPG', 141, 38, 117, 117, 'damaged'],
#  ['p92.JPG', 284, 45, 124, 125, 'damaged'],
#  ['p92.JPG', 429, 59, 92, 98, 'damaged'],
#  ['p92.JPG', 505, 122, 104, 109, 'damaged'],
#  ['p92.JPG', 68, 200, 96, 93, 'intact'],
#  ['p92.JPG', 192, 180, 94, 93, 'intact'],
#  ['p92.JPG', 306, 184, 94, 92, 'intact'],
#  ['p92.JPG', 410, 178, 91, 92, 'intact'],
#  ['p92.JPG', 96, 300, 88, 85, 'damaged'],
#  ['p92.JPG', 190, 295, 96, 95, 'damaged'],
#  ['p92.JPG', 302, 286, 109, 115, 'damaged'],
#  ['p92.JPG', 414, 283, 86, 90, 'intact'],
#  ['p92.JPG', 505, 249, 91, 88, 'damaged'],
#  ['p93.JPG', 36, 15, 124, 130, 'damaged'],
#  ['p93.JPG', 192, 26, 142, 140, 'damaged'],
#  ['p93.JPG', 353, 49, 108, 111, 'damaged'],
#  ['p93.JPG', 465, 59, 123, 128, 'damaged'],
#  ['p93.JPG', 29, 170, 121, 124, 'intact'],
#  ['p93.JPG', 191, 184, 108, 109, 'intact'],
#  ['p93.JPG', 332, 185, 109, 107, 'damaged'],
#  ['p93.JPG', 456, 200, 107, 108, 'damaged'],
#  ['p93.JPG', 51, 332, 102, 108, 'damaged'],
#  ['p93.JPG', 182, 312, 125, 121, 'damaged'],
#  ['p93.JPG', 328, 306, 103, 104, 'intact'],
#  ['p93.JPG', 447, 318, 100, 94, 'damaged'],
#  ['p94.JPG', 52, 6, 138, 136, 'damaged'],
#  ['p94.JPG', 215, 16, 141, 143, 'damaged'],
#  ['p94.JPG', 374, 42, 105, 110, 'damaged'],
#  ['p94.JPG', 477, 51, 118, 128, 'damaged'],
#  ['p94.JPG', 35, 172, 130, 126, 'intact'],
#  ['p94.JPG', 207, 184, 114, 106, 'intact'],
#  ['p94.JPG', 354, 180, 103, 106, 'damaged'],
#  ['p94.JPG', 477, 199, 99, 102, 'damaged'],
#  ...]

# %%
# Converting to DataFrame
df = pd.DataFrame(annotations, columns=["image_name", "x", "y", "width", "height", "label"])

# %%
df
# Out:
#      image_name    x    y  width  height    label
# 0        p1.JPG   70   46    120     112   intact
# 1        p1.JPG  195   60    118      99   intact
# 2        p1.JPG  318   25    144     120  damaged
# 3        p1.JPG  474   13    135     122   intact
# 4        p1.JPG   45  162    123     116   intact
# ...         ...  ...  ...    ...     ...      ...
# 1854     t1.JPG  232   34    147     146   intact
# 1855     t1.JPG  451   89    124     126   intact
# 1856     t1.JPG   80  248    138     138  damaged
# 1857     t1.JPG  244  284    146     150   intact
# 1858     t1.JPG  432  252    144     150  damaged
#
# [1859 rows x 6 columns]

# %% [markdown]
# # 1.5 Processing and saving the images

# %%
# Processing each image
for _, row in df.iterrows():
    img_path = os.path.join(image_folder, row["image_name"])
    
    if os.path.exists(img_path):
        image = cv2.imread(img_path)
        x, y, w, h = row["x"], row["y"], row["width"], row["height"]  # Grabbing the bounding box info from the DataFrame.
        
        # Cropping jar lid
        cropped = image[y:y+h, x:x+w] # Slicing the image array to get just the bounding box region.
        
        # Saving with label intact/damaged
        label = row["label"]
        save_path = os.path.join(output_dir, f"{row['image_name'].split('.')[0]}_{x}_{y}_{label}.jpg")
        cv2.imwrite(save_path, cropped)
    else:
        print(f"Image {img_path} not found!")

print("Cropping completed! 🚀")
# Out:
# Cropping completed! 🚀
